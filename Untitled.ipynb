# %%
import pandas as pd
df = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')

#See general infomation

print (f" number of clients: {len(df)}")
print (f" number of columns: {len (df.columns)}")
# Out:
#  number of clients: 9134
#  number of columns: 24

# %%
 # 1. Inspect the data types pandas assigns to each colum.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# # 3 Create a barplot of the number of customers per Gender
#
# ![image.png](attachment:99672ba0-1a09-41ba-bd85-65fd2f2c4e40.png)

# %% [markdown]
# # 4 Create a barplot of the number of customers per EmploymentStatus and Gender.
#
# ![image.png](attachment:fe544962-2f42-4519-97ca-a9d8b2c132e5.png)

# %% [markdown]
# # 5 Identify Measurements and Dimensions. Are they the same as the ones in your Pandas dataframe? Modify accordingly
#
# Yes, in this dataset, Tableu correctly identified the dimensions and measures as weel as Pandas DATA types.
#
#
# For gender analysis and employment analysis:  : ![Gender Analysis](unit-4-lab.twbx).
